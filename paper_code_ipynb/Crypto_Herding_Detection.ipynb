# %% [markdown]
# # **Importing Packages**

# %%
# !pip install "pandas == 2.0.3"
# !pip install "numpy == 1.25.2"
# !pip install "plotly == 5.15.0"
# !pip install "statsmodels.api == 0.14.2"
# !pip install "matplotlib == 3.7.1"
# !pip install "itertools == 3.10.12"
# !pip install "networkx == 3.1"
# !pip install "seaborn == 0.13.1"
# !pip install "community == 1.0.0b1"
# !pip install "sklearn == 1.2.2"
# Out:
# Collecting pandas==2.0.3
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3) (1.16.0)
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 53.8 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.0.3 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 2.0.3 which is incompatible.
# Successfully installed pandas-2.0.3
# Collecting numpy==1.25.2
#   Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 45.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 2.0.3 which is incompatible.
# Successfully installed numpy-1.25.2
# Collecting plotly==5.15.0
#   Downloading plotly-5.15.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly==5.15.0) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly==5.15.0) (24.1)
# Downloading plotly-5.15.0-py2.py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 38.6 MB/s eta 0:00:00
# ERROR: Operation cancelled by user

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
import itertools

def flatten_list(nested_list):
    return list(itertools.chain(*nested_list))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Reading Data**

# %%
# Read Cryptocurrency data
data_crypto = pd.read_csv("data/crypto_30min_filled_missing_value(ffill).csv")
data_crypto = data_crypto.set_index("date")

# %% [markdown]
# **Convert prices to returns**

# %%
# Find log-returns
names = data_crypto.columns
numpy_data = data_crypto.to_numpy()
original = numpy_data[:-1]
onelag = numpy_data[1:]
logreturns = np.log(onelag) - np.log(original)

return_data = pd.DataFrame(data = logreturns, columns = names)
return_data["date"] = data_crypto.index[1:]
return_data = return_data.set_index(['date'])

# %%
return_data_rm_UST = return_data.drop(columns = ["UST"]) # For the Ukraine-Russia period, as UST was no longer available at this time
names_rm_UST = return_data_rm_UST.columns

# %% [markdown]
# **Using 27 cryptocurrencies**

# %%
# Calculate the market return at each time point, i.e. the average return of all assets
market_return = pd.DataFrame(return_data.mean(axis=1), columns = ["mean market return"])
market_return.index = return_data.index

# %% [markdown]
# **Without UST**

# %%
# Calculate the market return at each time point, i.e. the average return of all assets
market_return = pd.DataFrame(return_data_rm_UST.mean(axis=1), columns = ["mean market return"])
market_return.index = return_data_rm_UST.index

# %%
fig_market_return = px.line(market_return, x='date', y= "mean market return", title='30-min market return')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-005afc3707fc> in <cell line: 1>()
# ----> 1 fig_market_return = px.line(market_return, x='date', y= "mean market return", title='30-min market return (crypto_stock_etf)')
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#     265
#     266
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2115     apply_default_cascade(args)
#    2116
# -> 2117     args = build_dataframe(args, constructor)
#    2118     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1511     # now that things have been prepped, we do the systematic rewriting of `args`
#    1512
# -> 1513     df_output, wide_id_vars = process_args_into_dataframe(
#    1514         args, wide_mode, var_name, value_name
#    1515     )
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1232                         if argument == "index":
#    1233                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234                         raise ValueError(err_msg)
#    1235                 elif length and len(df_input[argument]) != length:
#    1236                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['mean market return'] but received: date

# %%
fig_market_return

# %% [markdown]
# **Using 27 cryptocurrencies**

# %%
num_assets = len(names)
market_return_repeat = pd.concat([market_return] * num_assets, axis=1, ignore_index=True)
market_return_repeat.columns = return_data.columns

# %% [markdown]
# **Without UST**

# %%
num_assets = len(names_rm_UST)
market_return_repeat = pd.concat([market_return] * num_assets, axis=1, ignore_index=True)
market_return_repeat.columns = return_data_rm_UST.columns

# %%
market_return_repeat
# Out:
#                           ADA       BAT       BCH       BNT       BSV  \
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
#                           BTC       DAI      DASH      DOGE       EOS  ...  \
# date                                                                   ...
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607  ...
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912  ...
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903  ...
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323  ...
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725  ...
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636  ...
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043  ...
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317  ...
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564  ...
#
#                           REP       TRX      USDT       XLM       XMR  \
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
#                           XRP       XTZ       XVG       ZEC       ZRX
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
# [71903 rows x 26 columns]

# %% [markdown]
# # **Herding Detection**

# %% [markdown]
# ---
#
#
# We use the Cross-Sectional Absolute Deviation (CSAD) model to detect the herding behavior in financial markets. This is one of the most well-known herding behavior detection approaches that has been used widely in many studies.
#
# The fundamental idea of this technique is to examine the relationship between the average return (market return) of a set of assets and the dispersion across each asset return (CSAD). A herding signal is pronounced when the market return changes significantly (i.e. the market experiences large fluctuations, either going up or down) while the dispersion between asset returns decreases (i.e. the return movements of different assets become more similar). In this study, we use two forms of the CSAD model for our experiments.
# + $CSAD_t = \beta_0 + \beta_1|r_{m,t}| + \beta_2 r_{m,t}^2 + \epsilon_t$
# + $CSAD_t = \gamma_0 + \gamma_1 D^{up} |r_{m,t}| + \gamma_2 D^{up} r_{m,t}^2 + \gamma_3 D^{down} |r_{m,t}| + \gamma_4 D^{down} r_{m,t}^2 + \zeta_t$
#
# Where $CSAD_t = \sum\limits_{k = 1}^T |r_{i,t} - r_{m,t}| / T$; $r_{i,t}$ is the return of asset $i$ at time $t$; $r_{m,t} = \sum\limits_{k = 1}^{N} r_{k,t} / N $ is the average of asset returns (also known as the market return) at time $t$; $\beta_0, \beta_1, \beta_2, \gamma_0, \gamma_1, \gamma_2, \gamma_3, \gamma_4$ are regression coefficients, $D^{up} = 1$ if $r_{m,t}$ is positive, otherwise $0$; $D^{down} = 1$ if $r_{m,t}$ is negative, otherwise $0$; $\epsilon_t, \zeta_t$ are error terms at time $t$.
#
# Regarding the first equation, a herding exists when the parameter $\beta_2$ is significantly negative (a negative coefficient with a confidence level of at least 90\%). Intuitively, we expect this coefficient to be negative because it follows the idea of the herding behavior, i.e. a dramatic increase or decrease in the market return ($r_{m,t}^2$) coincides with a decline (negative $\beta_2$) in the dispersion between corresponding assets' returns ($CSAD_t$). The second equation refers to a more detailed version of the first one in which we separate the market condition into $\textit{up}$ (i.e. positive market return) and $\textit{down}$ (i.e. non-positive market return) so that the herding can be detected during the $\textit{up}$ and $\textit{down}$ market condition separately, instead of considering all market conditions (i.e. both $\textit{up}$ and $\textit{down}$ equally) as declared in the first form. The use of both forms for herding detection comes from an expectation that there might be periods when herding does not exist when considering both up and down market conditions at the same time but it might be found in the $\textit{up}$ or $\textit{down}$ market condition only. To this end, the same logic of the first equation is applied to the second equation wherein a significantly negative $\gamma_2$ refers to a herding signal during the $\textit{up}$ market condition while a significantly negative $\gamma_3$ refers to a herding signal during the $\textit{down}$ market condition.
#
#
# ---

# %% [markdown]
# ---
#
#
# **NOTE: The code below is for the entire data comprising of three types of investment vehicle as described in the paper. If you want to run herding detection on one particular type of investment vehicle only, change the "Reading Data" section at the beginning of this script to that appropriate data**
#
# ---

# %% [markdown]
# **Calculating CSAD and other features**

# %% [markdown]
# **Using 27 cryptocurrencies**

# %%
csad = np.sum(np.abs(return_data - market_return_repeat), axis = 1)/num_assets

# %% [markdown]
# **Without UST**

# %%
csad = np.sum(np.abs(return_data_rm_UST - market_return_repeat), axis = 1)/num_assets

# %%
rmt = market_return.values
rmt_abs = np.abs(market_return.values)
rmt_squared = (market_return.values)**2
alpha = np.ones(len(market_return))
variables_csad = pd.DataFrame(data = np.asarray([csad.values, alpha, np.squeeze(rmt), np.squeeze(rmt_abs), np.squeeze(rmt_squared)]).T, columns = ["csad", "alpha", "rmt", "rmt_abs", "rmt_squared"])

# %%
variables_csad.index = market_return.index

# %% [markdown]
# # **Timeline Partition**

# %% [markdown]
# + Time window 1: Start - 12.2019: [:13199]
#
# + Time window 2: 01.2020 - 06.2020 [13199:21935]
#
# + Time window 3: 07.2020 - 01.2021 [21935:32255]
#
# + Time window 4: 02.2021 - 08.2021 [32255:42431]
#
# + Time window 5: 09.2021 - 23.02.2022 [42431:50879]
#
# + Time window 6: 24.02.2022 - 09.2022 [50879:61391]
#
# + Time window 7: 10.2022 - end [61391:71711]

# %% [markdown]
# **Forming a regression model to estimate the parameters of the herding detection equation**

# %% [markdown]
# **Entire Period**

# %%
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']]
Y = variables_csad["csad"]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                 3.746e+04
# Date:                Wed, 06 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:03:10   Log-Likelihood:             2.6658e+05
# No. Observations:               71903   AIC:                        -5.332e+05
# Df Residuals:                   71900   BIC:                        -5.331e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0020   2.96e-05     66.296      0.000       0.002       0.002
# rmt_abs         1.0772      0.005    213.643      0.000       1.067       1.087
# rmt_squared    -1.7514      0.079    -22.250      0.000      -1.906      -1.597
# ==============================================================================
# Omnibus:                    55471.769   Durbin-Watson:                   1.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3134641.937
# Skew:                           3.235   Prob(JB):                         0.00
# Kurtosis:                      34.693   Cond. No.                     3.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Sub-periods**

# %%
# start - 12/2019
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][:13199]
Y = variables_csad["csad"][:13199]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                 1.034e+04
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:45:16   Log-Likelihood:                 56610.
# No. Observations:               13199   AIC:                        -1.132e+05
# Df Residuals:                   13196   BIC:                        -1.132e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0030   3.97e-05     76.565      0.000       0.003       0.003
# rmt_abs         0.7202      0.009     76.262      0.000       0.702       0.739
# rmt_squared     6.2412      0.210     29.790      0.000       5.831       6.652
# ==============================================================================
# Omnibus:                     5966.934   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           605472.074
# Skew:                           1.223   Prob(JB):                         0.00
# Kurtosis:                      36.090   Cond. No.                     7.25e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.25e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 2  01.2020 - 06.2020 [13199:21935]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][13199:21935]
Y = variables_csad["csad"][13199:21935]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     7289.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:44:33   Log-Likelihood:                 36166.
# No. Observations:                8736   AIC:                        -7.233e+04
# Df Residuals:                    8733   BIC:                        -7.231e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0022    5.7e-05     38.898      0.000       0.002       0.002
# rmt_abs         1.0316      0.010    101.767      0.000       1.012       1.051
# rmt_squared    -4.7313      0.144    -32.905      0.000      -5.013      -4.449
# ==============================================================================
# Omnibus:                     3088.299   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22090.303
# Skew:                           1.512   Prob(JB):                         0.00
# Kurtosis:                      10.180   Cond. No.                     3.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 3  07.2020 - 01.2021 [21935:32255]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][21935:32255]
Y = variables_csad["csad"][21935:32255]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     4371.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:46:51   Log-Likelihood:                 42720.
# No. Observations:               10320   AIC:                        -8.543e+04
# Df Residuals:                   10317   BIC:                        -8.541e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0038   5.86e-05     64.541      0.000       0.004       0.004
# rmt_abs         0.8627      0.012     69.137      0.000       0.838       0.887
# rmt_squared    -6.7909      0.384    -17.701      0.000      -7.543      -6.039
# ==============================================================================
# Omnibus:                     3337.176   Durbin-Watson:                   1.458
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13600.084
# Skew:                           1.557   Prob(JB):                         0.00
# Kurtosis:                       7.683   Cond. No.                     1.01e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 4  02.2021 - 08.2021 [32255:42431]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][32255:42431]
Y = variables_csad["csad"][32255:42431]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.574
# Method:                 Least Squares   F-statistic:                     6861.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:47:46   Log-Likelihood:                 31131.
# No. Observations:               10176   AIC:                        -6.226e+04
# Df Residuals:                   10173   BIC:                        -6.223e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0032      0.000     20.430      0.000       0.003       0.003
# rmt_abs         1.4803      0.016     95.134      0.000       1.450       1.511
# rmt_squared    -3.7684      0.196    -19.250      0.000      -4.152      -3.385
# ==============================================================================
# Omnibus:                     2960.959   Durbin-Watson:                   1.360
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17383.391
# Skew:                           1.267   Prob(JB):                         0.00
# Kurtosis:                       8.880   Cond. No.                     1.74e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 5  09.2021 - 23.02.2022 [42431:50879]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][42431:50879]
Y = variables_csad["csad"][42431:50879]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     3581.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:49:35   Log-Likelihood:                 42934.
# No. Observations:                8448   AIC:                        -8.586e+04
# Df Residuals:                    8445   BIC:                        -8.584e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0029   2.35e-05    124.504      0.000       0.003       0.003
# rmt_abs         0.2367      0.005     51.624      0.000       0.228       0.246
# rmt_squared     1.0135      0.060     16.893      0.000       0.896       1.131
# ==============================================================================
# Omnibus:                     4069.577   Durbin-Watson:                   1.284
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34126.823
# Skew:                           2.139   Prob(JB):                         0.00
# Kurtosis:                      11.869   Cond. No.                     3.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 6   24.02.2022 - 09.2022 [50879:61391]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][50879:61391]
Y = variables_csad["csad"][50879:61391]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.342
# Method:                 Least Squares   F-statistic:                     2733.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:50:27   Log-Likelihood:                 49692.
# No. Observations:               10512   AIC:                        -9.938e+04
# Df Residuals:                   10509   BIC:                        -9.936e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0031   3.17e-05     97.388      0.000       0.003       0.003
# rmt_abs         0.3416      0.007     47.104      0.000       0.327       0.356
# rmt_squared     0.4652      0.224      2.077      0.038       0.026       0.904
# ==============================================================================
# Omnibus:                     6532.147   Durbin-Watson:                   1.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154331.519
# Skew:                           2.573   Prob(JB):                         0.00
# Kurtosis:                      21.052   Cond. No.                     1.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time Window 7   10.2022 - end [61391:71711]
X = variables_csad[['alpha', 'rmt_abs', 'rmt_squared']][61391:71711]
Y = variables_csad["csad"][61391:71711]

## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     3310.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        12:51:30   Log-Likelihood:                 48003.
# No. Observations:               10320   AIC:                        -9.600e+04
# Df Residuals:                   10317   BIC:                        -9.598e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# alpha           0.0020    3.4e-05     58.616      0.000       0.002       0.002
# rmt_abs         0.7303      0.011     67.462      0.000       0.709       0.752
# rmt_squared    -9.1943      0.396    -23.196      0.000      -9.971      -8.417
# ==============================================================================
# Omnibus:                     4991.268   Durbin-Watson:                   1.330
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43925.573
# Skew:                           2.134   Prob(JB):                         0.00
# Kurtosis:                      12.162   Cond. No.                     1.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Second Equation: CSAD for Up and Down Markets**

# %%
D_up_R_abs = market_return["mean market return"].apply(lambda x: x if x > 0.0 else 0.0)
D_up_R_squared = market_return["mean market return"].apply(lambda x: x**2 if x> 0.0 else 0.0)
D_down_R_abs = market_return["mean market return"].apply(lambda x: np.abs(x) if x < 0.0 else 0.0)
D_down_R_squared = market_return["mean market return"].apply(lambda x: x**2 if x < 0.0 else 0.0)
alpha = np.ones(len(market_return))

variables_csad = pd.DataFrame(data = np.asarray([csad.values, alpha, D_up_R_abs, D_up_R_squared, D_down_R_abs, D_down_R_squared]).T, columns = ["csad", "alpha", "duprabs","duprsquared","ddownrabs","ddownrsquared"])

# %%
variables_csad.index = market_return.index

# %%
market_return_repeat
# Out:
#                           ADA       BAT       BCH       BNT       BSV  \
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
#                           BTC       DAI      DASH      DOGE       EOS  ...  \
# date                                                                   ...
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607  ...
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912  ...
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903  ...
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323  ...
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725  ...
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636  ...
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043  ...
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317  ...
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564  ...
#
#                           REP       TRX      USDT       XLM       XMR  \
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
#                           XRP       XTZ       XVG       ZEC       ZRX
# date
# 2019-04-01 00:30:00  0.009607  0.009607  0.009607  0.009607  0.009607
# 2019-04-01 01:00:00  0.007912  0.007912  0.007912  0.007912  0.007912
# 2019-04-01 01:30:00 -0.002903 -0.002903 -0.002903 -0.002903 -0.002903
# 2019-04-01 02:00:00  0.001323  0.001323  0.001323  0.001323  0.001323
# 2019-04-01 02:30:00  0.003180  0.003180  0.003180  0.003180  0.003180
# ...                       ...       ...       ...       ...       ...
# 2023-05-07 21:30:00 -0.002725 -0.002725 -0.002725 -0.002725 -0.002725
# 2023-05-07 22:00:00  0.000636  0.000636  0.000636  0.000636  0.000636
# 2023-05-07 22:30:00 -0.000043 -0.000043 -0.000043 -0.000043 -0.000043
# 2023-05-07 23:00:00  0.000317  0.000317  0.000317  0.000317  0.000317
# 2023-05-07 23:30:00 -0.009564 -0.009564 -0.009564 -0.009564 -0.009564
#
# [71903 rows x 26 columns]

# %% [markdown]
# **Entire Period**

# %%
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']]
Y = variables_csad["csad"]
X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                 1.935e+04
# Date:                Wed, 06 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:04:24   Log-Likelihood:             2.6718e+05
# No. Observations:               71903   AIC:                        -5.343e+05
# Df Residuals:                   71898   BIC:                        -5.343e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0021   3.02e-05     71.182      0.000       0.002       0.002
# duprabs           0.9905      0.008    126.450      0.000       0.975       1.006
# duprsquared       3.4645      0.195     17.725      0.000       3.081       3.848
# ddownrabs         1.0286      0.006    175.284      0.000       1.017       1.040
# ddownrsquared    -2.2582      0.083    -27.188      0.000      -2.421      -2.095
# ==============================================================================
# Omnibus:                    54805.095   Durbin-Watson:                   1.185
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3677482.103
# Skew:                           3.112   Prob(JB):                         0.00
# Kurtosis:                      37.478   Cond. No.                     8.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Sub-Period**

# %%
# Pre-Covid-19: start - 12/2019
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][:13199]
Y = variables_csad["csad"][:13199]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     5419.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:39:15   Log-Likelihood:                 56802.
# No. Observations:               13199   AIC:                        -1.136e+05
# Df Residuals:                   13194   BIC:                        -1.136e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0030   3.92e-05     76.811      0.000       0.003       0.003
# duprabs           0.7575      0.012     65.149      0.000       0.735       0.780
# duprsquared       8.9781      0.294     30.539      0.000       8.402       9.554
# ddownrabs         0.6979      0.012     60.666      0.000       0.675       0.720
# ddownrsquared     4.4681      0.270     16.572      0.000       3.940       4.997
# ==============================================================================
# Omnibus:                     8665.128   Durbin-Watson:                   1.285
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1138212.204
# Skew:                           2.232   Prob(JB):                         0.00
# Kurtosis:                      48.274   Cond. No.                     1.05e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Covid-19: 01.2020 - 06.2020 [13199:21935]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][13199:21935]
Y = variables_csad["csad"][13199:21935]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     4050.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        13:47:37   Log-Likelihood:                 36679.
# No. Observations:                8736   AIC:                        -7.335e+04
# Df Residuals:                    8731   BIC:                        -7.331e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0021    5.4e-05     39.795      0.000       0.002       0.002
# duprabs           1.0784      0.013     82.135      0.000       1.053       1.104
# duprsquared      -4.3471      0.252    -17.223      0.000      -4.842      -3.852
# ddownrabs         1.0183      0.012     86.503      0.000       0.995       1.041
# ddownrsquared    -4.6894      0.170    -27.634      0.000      -5.022      -4.357
# ==============================================================================
# Omnibus:                     3070.406   Durbin-Watson:                   1.486
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20720.764
# Skew:                           1.521   Prob(JB):                         0.00
# Kurtosis:                       9.905   Cond. No.                     6.53e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Bull Time 1: 07.2020 - 01.2021 [21935:32255]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][21935:32255]
Y = variables_csad["csad"][21935:32255]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     2408.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        13:51:51   Log-Likelihood:                 43227.
# No. Observations:               10320   AIC:                        -8.644e+04
# Df Residuals:                   10315   BIC:                        -8.641e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0037   5.79e-05     63.189      0.000       0.004       0.004
# duprabs           0.9113      0.020     45.649      0.000       0.872       0.950
# duprsquared      -6.4200      1.080     -5.942      0.000      -8.538      -4.302
# ddownrabs         0.8395      0.014     58.720      0.000       0.811       0.868
# ddownrsquared    -6.1360      0.418    -14.664      0.000      -6.956      -5.316
# ==============================================================================
# Omnibus:                     3385.404   Durbin-Watson:                   1.469
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13673.287
# Skew:                           1.586   Prob(JB):                         0.00
# Kurtosis:                       7.663   Cond. No.                     3.00e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Bull Time 2: 02.2021 - 08.2021 [32255:42431]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][32255:42431]
Y = variables_csad["csad"][32255:42431]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     3582.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        13:55:28   Log-Likelihood:                 31630.
# No. Observations:               10176   AIC:                        -6.325e+04
# Df Residuals:                   10171   BIC:                        -6.321e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0035      0.000     22.348      0.000       0.003       0.004
# duprabs           1.3443      0.030     45.377      0.000       1.286       1.402
# duprsquared       0.4969      0.677      0.734      0.463      -0.830       1.824
# ddownrabs         1.4617      0.018     80.551      0.000       1.426       1.497
# ddownrsquared    -3.9754      0.207    -19.184      0.000      -4.382      -3.569
# ==============================================================================
# Omnibus:                     3150.970   Durbin-Watson:                   1.352
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22214.309
# Skew:                           1.301   Prob(JB):                         0.00
# Kurtosis:                       9.755   Cond. No.                     6.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Bull Time 3: 09.2021 - 23.02.2022 [42431:50879]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][42431:50879]
Y = variables_csad["csad"][42431:50879]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     2353.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:11:42   Log-Likelihood:                 43378.
# No. Observations:                8448   AIC:                        -8.675e+04
# Df Residuals:                    8443   BIC:                        -8.671e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0028   2.28e-05    124.264      0.000       0.003       0.003
# duprabs           0.2781      0.007     41.931      0.000       0.265       0.291
# duprsquared       2.2923      0.199     11.500      0.000       1.902       2.683
# ddownrabs         0.2547      0.005     49.702      0.000       0.245       0.265
# ddownrsquared     1.0751      0.064     16.684      0.000       0.949       1.201
# ==============================================================================
# Omnibus:                     3928.671   Durbin-Watson:                   1.289
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30103.335
# Skew:                           2.080   Prob(JB):                         0.00
# Kurtosis:                      11.259   Cond. No.                     1.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time window 6: 24.02.2022 - 09.2022 [50879:61391]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][50879:61391]
Y = variables_csad["csad"][50879:61391]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     1370.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:39:22   Log-Likelihood:                 49697.
# No. Observations:               10512   AIC:                        -9.938e+04
# Df Residuals:                   10507   BIC:                        -9.935e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0031   3.29e-05     93.553      0.000       0.003       0.003
# duprabs           0.3613      0.011     31.608      0.000       0.339       0.384
# duprsquared       0.0358      0.543      0.066      0.947      -1.028       1.100
# ddownrabs         0.3294      0.008     40.497      0.000       0.313       0.345
# ddownrsquared     0.6319      0.236      2.680      0.007       0.170       1.094
# ==============================================================================
# Omnibus:                     6568.225   Durbin-Watson:                   1.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158950.030
# Skew:                           2.585   Prob(JB):                         0.00
# Kurtosis:                      21.335   Cond. No.                     2.60e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Time window 7: 10.2022 - end [61391:71711]
X = variables_csad[['alpha', 'duprabs', 'duprsquared', 'ddownrabs', 'ddownrsquared']][61391:71711]
Y = variables_csad["csad"][61391:71711]
# X = sm.add_constant(X)
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   csad   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     1675.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):               0.00
# Time:                        14:40:53   Log-Likelihood:                 48028.
# No. Observations:               10320   AIC:                        -9.605e+04
# Df Residuals:                   10315   BIC:                        -9.601e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# alpha             0.0020   3.42e-05     57.604      0.000       0.002       0.002
# duprabs           0.7960      0.014     55.455      0.000       0.768       0.824
# duprsquared     -11.9781      0.737    -16.249      0.000     -13.423     -10.533
# ddownrabs         0.6883      0.012     55.169      0.000       0.664       0.713
# ddownrsquared    -7.8995      0.444    -17.776      0.000      -8.771      -7.028
# ==============================================================================
# Omnibus:                     5046.149   Durbin-Watson:                   1.333
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            46048.788
# Skew:                           2.150   Prob(JB):                         0.00
# Kurtosis:                      12.413   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
